# %%
import pandas as pd
import urllib.request, json 
from urllib.request import urlopen
import re
from bs4 import BeautifulSoup
import PyPDF2
import os
from os import walk
import os.path
from os import path
import numpy as np
#!pip install py-readability-metrics
from readability import Readability
#!python -m nltk.downloader punkt

import time
from datetime import date

# %%
def reCase(text):
    output = re.sub("(\w|\d)(_|-)(\w|\d)","\\1 \\3",text)
    output = re.sub("([a-z])([A-Z]|\d)","\\1 \\2",output)
    output = re.sub("(\d)([A-Z]|[a-z])","\\1 \\2",output)
    return output

# %%
def read_pdf (file):
    try:
        pdfFile = PyPDF2.PdfFileReader(open(file, "rb"))
        if pdfFile.isEncrypted:
            try:
                pdfFile.decrypt('')
                #print ('File Decrypted (PyPDF2)')
            except:
                #
                #
                # This didn't go so well on my Windows box so I just ran this in the pdf folder's cmd:
                # for %f in (*.*) do copy %f temp.pdf /Y && "C:\Program Files (x86)\qpdf-8.0.2\bin\qpdf.exe" --password="" --decrypt temp.pdf %f
                #
                #
                #
                
                command="cp "+file+" tmp/temp.pdf; qpdf --password='' --decrypt tmp/temp.pdf "+file
                os.system(command)
                #print ('File Decrypted (qpdf)')
                #re-open the decrypted file
                pdfFile = PyPDF2.PdfFileReader(open(file, "rb"))
        text = ""
        for page in pdfFile.pages:
            text = text + " " + page.extractText()
        return text
    except:
        return ""

# %%
def parse_form(fileloc,title=None,cat=None):
    f = PyPDF2.PdfFileReader(fileloc)
    npages = f.getNumPages()
    ff = f.getFields()
    if ff:
        fields = list(ff.keys())
    else:
        fields = []
    f_per_page = len(fields)/npages
    text = read_pdf(fileloc)
    try:
        readbility = int(Readability(text).flesch_kincaid().grade_level)
    except:
        readbility = None
    
    if title is None:
        title = reCase(re.search("(.*)\n",text).group(1).strip())
    
    stats = {
            "title":title,
            "category":cat,
            "pages":npages,
            "reading grade level": readbility,
            "avg fields per page": f_per_page,
            "fields":fields
            }    
    return stats

# %%
files_df_ut = pd.read_csv("../data/raw/www.utcourts.gov/form_data.csv")
files_df_mi = pd.read_csv("../data/raw/www.courts.michigan.gov/form_data.csv")

df = pd.concat([files_df_ut,files_df_mi],ignore_index=True)
df["pages"] = ""
df["fields"] = ""
df["f_per_p"] = ""
df["reading"] = ""

for index,row in df.iterrows():
    if row["pages"] == "":
        stats = parse_form("../data/raw/"+row["source"]+"/forms/"+row["id"]+".pdf",row["title"],row["group"])
        df.at[index, 'pages'] = stats["pages"]
        df.at[index, 'fields'] = stats["fields"]
        df.at[index, 'f_per_p'] = stats["avg fields per page"]
        df.at[index, 'reading'] = stats["reading grade level"]
        #print(index)
        
df
# Out:
# PdfReadWarning: Xref table not zero-indexed. ID numbers for objects will be corrected. [pdf.py:1736]
#                                   id jurisdiction                   source  \
# 0   ed1efd08e3304bdaa887db753509d666           UT         www.utcourts.gov
# 1   28ab1fb8df5c477cb4353e44f6d5a404           UT         www.utcourts.gov
# 2   279083cdac044d22b873a6a6ab8d9a14           UT         www.utcourts.gov
# 3   ebad2caa6be0458d9e5c75635a7f66c2           UT         www.utcourts.gov
# 4   92932e4f938440ce8b93b6434aedfc3d           UT         www.utcourts.gov
# 5   346d754e93274e83bfa8e73e0c651b1d           MI  www.courts.michigan.gov
# 6   57f56df055254cde9ecd9ce217b9dca3           MI  www.courts.michigan.gov
# 7   5e89ca0faf59435d9d668abe9704b37f           MI  www.courts.michigan.gov
# 13  Acceptance of Receivership Appointment (Receiv...
# 14  Application and Ex Parte Order to File Lien on...
# 15                          Binding Arbitration Award
# 16  Order on Petition to Discontinue Sex Offender ...
# 17                          Acceptance of Appointment
# 18  Clerk's Certificate of Sale of Real Estate Pur...
# 19              Assignment to Youthful Trainee Status
# 20  Instructions for Personal Protection Orders (8...
# 21                     Minor's Consent to Change Name
# 22  Addendum to Protected Personal Identifying Inf...
# 23      Acceptance of Appointment (Juvenile Guardian)
# 24  Advice of Rights after Order Terminating Paren...
# 25  21-Day Notice to Alleged Violator of Custody o...
# 26  Acceptance of Appointment and Report of Guardi...
# 27  Appeal of Order Denying Petition for Waiver of...
# 28  Advice of Rights and Plea Information (also av...
# 29  Order Following Hearing on Petition for Emanci...
# 30             Blank (does not contain SCAO approval)
# 31  Affidavit to Accompany Petition for Transport ...
# 32  Certificate of Legal Counsel/Waiver of Attendance
# 33  Acceptance of Appointment and Report of Guardi...
# 34              Advice of Rights (Circuit Court Plea)
# 35           Judgment of Conviction (Designated Case)
# 36  Motion Objecting to DNA Identification Profile...
# 37                             Case Evaluation Notice
# 38                  Affidavit and Claim, Small Claims
# 39                    14-Day Notice, Civil Infraction
#
#                                                group  \
# 0   3rd District Juvenile Court: Forms and Pamphlets
# 1   3rd District Juvenile Court: Forms and Pamphlets
# 2   3rd District Juvenile Court: Forms and Pamphlets
# 3                         Adopting a Minor Stepchild
# 4                         Adopting a Minor Stepchild
# 5                                         LTLC forms
# 6                              adoptions court forms
# 7                       motor vehicle offenses forms
# 8                                          probation
# 9                                 claim and delivery
# 10                     young adult foster care forms
# 11                                           appeals
# 12                                       garnishment
# 13                               General Civil forms
# 14                                        forfeiture
# 15                           Alternative dispute res
# 16                             Offender Registration
# 17                                    Estates Trusts
# 18                              Mortgage foreclosure
# 19                        Criminal disposition forms
# 20                                               PPO
# 21                                       name change
# 22                                       general use
# 23                       juvenile guardianship forms
# 24                              juvenile proceedings
# 25                                Domestic Relations
# 26             conservatorship protected individuals
# 27                                   Abortion Waiver
# 28                        forms criminal misdemeanor
# 29                                      emancipation
# 30                                 Collections Forms
# 31                             commitment testing ID
# 32                                          MH Forms
# 33                                      guardianship
# 34                             criminal felony forms
# 35                         juvenile designated forms
# 36                             safe delivery newborn
# 37                                   case evaluation
# 38                                      small claims
# 39                                  civil infraction
#
#                                                   url  \
# 0   https://www.utcourts.gov/courts/juv/juvsites/3...
# 1   https://www.utcourts.gov/courts/juv/juvsites/3...
# 2   https://www.utcourts.gov/courts/juv/juvsites/3...
# 3   https://www.utcourts.gov/howto/family/adoption...
# 4   https://www.utcourts.gov/howto/family/adoption...
# 5   https://www.courts.michigan.gov/4a205c/siteass...
# 6   https://www.courts.michigan.gov/49c512/siteass...
# 7   https://www.courts.michigan.gov/4a70d4/siteass...
# 8   https://www.courts.michigan.gov/4a2d6f/siteass...
# 9   https://www.courts.michigan.gov/4a2da7/siteass...
# 10  https://www.courts.michigan.gov/4a800a/siteass...
# 11  https://www.courts.michigan.gov/4a7fed/siteass...
# 12  https://www.courts.michigan.gov/4a7f4b/siteass...
# 13  https://www.courts.michigan.gov/4a3c82/siteass...
# 14  https://www.courts.michigan.gov/4a2bfa/siteass...
# 35                                           jc70.pdf  2021-11-03     2
# 36                                         ccfd05.pdf  2021-11-03     1
# 37                                           mc31.pdf  2021-11-03     2
# 38                                           dc84.pdf  2021-11-03     4
# 39                                          cia03.pdf  2021-11-03     1
#
#                                                fields f_per_p reading
# 0                                                  []     0.0      10
# 1                                                  []     0.0      11
# 2                                                  []     0.0      15
# 3                                                  []     0.0      10
# 4                                                  []     0.0      11
# 5   [STATE OF MICHIGAN JUDICIAL DISTRICT, CASE NO,...    23.5       7
# 6   [STATE OF MICHIGAN JUDICIAL CIRCUIT  FAMILY DI...    26.0       6
# 7                                                  []     0.0      14
# 8   [Date, Probation officer, were, did, did_2, di...    22.0       9
# 9   [disno, cirno, county, caseno, judge, address,...    30.0      18
# 10  [county, FILE NO, Name of youth, DOB, Race, Ge...    19.0      17
# 11  [cirno, county, caseno, address, telno, dname,...    33.0      16
# 12  [STATE OF MICHIGAN JUDICIAL DISTRICT JUDICIAL ...    16.0      17
# 13  [CASE NO, Plaintiffs names addresses and telep...    18.0      12
# 14  [STATE OF MICHIGAN JUDICIAL DISTRICT, CASE NO,...    28.0      17
# 15  [witnesses, exhibits, disno, cirno, county, ca...    21.0      17
# 16  [CASE NO, Defendants name address and telephon...    30.0      15
# 17  [STATE OF MICHIGAN PROBATE COURT COUNTY, First...    25.0      11
# 18  [cirno, county, caseno, address, telno, pname,...    19.0      21
# 19  [STATE OF MICHIGAN JUDICIAL DISTRICT JUDICIAL ...    27.5      10
# 20                                                 []     0.0      11
# 21  [FILE NO, Present first name middle name and l...     9.0    None
# 22  [PlaintiffsPetitioners name, DefendantsRespond...    39.0      10
# 23  [STATE OF MICHIGAN JUDICIAL CIRCUIT  FAMILY DI...    14.0    None
# 24  [STATE OF MICHIGAN JUDICIAL CIRCUIT  FAMILY DI...    18.5      11
# 25  [Plaintiffs name address and telephone no, Def...    11.0       8
# 26  [county, fileno, casename, name, report, recom...     5.5      30
# 27  [cirno, county, caseno, judge, pname, hdate, h...     3.5      26
# 28  [STATE OF MICHIGAN JUDICIAL DISTRICT, CASE NO,...     9.0       8
# 29  [Text3, Minors Social Security No, STATE OF MI...     7.5       9
# 30  [court, title, caseno, judge, address, telno, ...     7.0    None
# 31  [cirno, county, caseno, casename, name, diseas...    19.0      33
# 32  [county, cirno, caseno, casename, hdate, htime...    15.0      18
# 33  [STATE OF MICHIGAN PROBATE COURT COUNTY OF, FI...    20.5      11
# 34  [STATE OF MICHIGAN JUDICIAL CIRCUIT COUNTY, CA...    11.0      14
# 35  [STATE OF MICHIGAN JUDICIAL CIRCUIT  FAMILY DI...    29.0       9
# 36  [cir, county, filenumber, name, box2a, box2b, ...    18.0      26
# 37  [disno, cirno, county, caseno, judge, address,...    21.0      19
# 38  [STATE OF MICHIGAN JUDICIAL DISTRICT, See addi...    24.5       9
# 39  [STATE OF MICHIGAN JUDICIAL DISTRICT, Civil In...    18.0       9

# %%
df.to_csv("../data/processed/form_data.csv", index=False, encoding="utf-8")

# %%
os.system('cp ../data/processed/form_data.csv docs/forms/form_data.csv')
os.system('cp ../data/raw/www.utcourts.gov/forms/* docs/forms/')
os.system('cp ../data/raw/www.courts.michigan.gov/forms/* docs/forms/')
# Out:
# 0
