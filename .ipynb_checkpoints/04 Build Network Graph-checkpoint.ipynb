# %%
import pandas as pd
import networkx as nx
import numpy as np
import json

from matplotlib.pyplot import figure

from pyvis.network import Network

#https://towardsdatascience.com/from-dataframe-to-network-graph-bbb35c8ab675

# %%
shared_fields = pd.read_csv("docs/forms/form_data.csv")
shared_fields = shared_fields[["id","jurisdiction","title","fields"]]
shared_fields
# Out:
#                                     id jurisdiction  \
# 0     ed1efd08e3304bdaa887db753509d666           UT
# 1     28ab1fb8df5c477cb4353e44f6d5a404           UT
# 2     279083cdac044d22b873a6a6ab8d9a14           UT
# 3     ebad2caa6be0458d9e5c75635a7f66c2           UT
# 4     92932e4f938440ce8b93b6434aedfc3d           UT
# ...                                ...          ...
# 1524  94be7e4a467c46c5b8f18a81df4c3371           MI
# 1525  9d46a79a162844ebb78fc592873c027b           MI
# 1526  6d97d3ca4103413b8e161013c26943d6           MI
# 1527  480c76eb519d4242a7f44722bb7fbea6           MI
# 1528  e4108c7222334e2fa7bf8dee2d80a842           MI
#
#                                                   title  \
# 0     Community Service Worksheet Third District Juv...
# 1     Third District Juvenile Court Work Program Ref...
# 2     Utah State District Juvenile Court Probation O...
# 3     Adoptee's Consent to Adoption and Waiver of Ri...
# 4                                   Adoption Agreement
# ...                                                 ...
# 1524  Claim of Appeal of Right/Request to Withdraw A...
# 1525                 Default Judgment, Civil Infraction
# 1526                         Judgment, Civil Infraction
# 1527  Motion to Set Aside Default Judgment and Order...
# 1528                 Notice to Appear, Civil Infraction
#
#                                                  fields
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 1524  ['disno', 'caseno', 'judge', 'address', 'telno...
# 1525                                                 []
# 1526  ['STATE OF MICHIGAN JUDICIAL DISTRICT COUNTY',...
# 1527  ['disno', 'caseno', 'judge', 'address', 'telno...
# 1528                                                 []
#
# [1529 rows x 4 columns]

# %%
jur = "MI"
df_slice = shared_fields[shared_fields["jurisdiction"]==jur][:20]
network_df = pd.DataFrame([],columns=["form_1","form_2"])
for index,row in df_slice.iterrows():
    if pd.notnull(row["fields"]) and row["fields"]!="[]":
        field_list = eval(row["fields"])
        #print("\n\n")
        #print(field_list)
        
        for f in field_list:
            tmp_df = df_slice.copy()
            tmp_df["match"] = tmp_df["fields"].str.contains("'%s'"%f)
            tmp_df = tmp_df[tmp_df["match"]==True]
            for index_2,row_2 in tmp_df.iterrows():
                #print(f,row["title"],"<-->",row_2["title"])
                if row["id"]!=row_2["id"]:
                    network_df = network_df.append(pd.DataFrame([[row["title"],row_2["title"]]],columns=["form_1","form_2"]), ignore_index=True,sort=False)
                
network_df
# Out:
#                                                  form_1  \
# 0     Answer to Complaint to Recover Possession of P...
# 1     Answer to Complaint to Recover Possession of P...
# 2     Answer to Complaint to Recover Possession of P...
# 3     Answer to Complaint to Recover Possession of P...
# 4     Answer to Complaint to Recover Possession of P...
# ...                                                 ...
# 1027  Advice of Rights after Order Terminating Paren...
# 1028  Advice of Rights after Order Terminating Paren...
# 1029  Advice of Rights after Order Terminating Paren...
# 1030  Advice of Rights after Order Terminating Paren...
# 1031  Advice of Rights after Order Terminating Paren...
#
#                                                  form_2
# 0     Application and Ex Parte Order to File Lien on...
# 1         Motion and Order for Discharge From Probation
# 2     Final Statement on Garnishment of Periodic Pay...
# 3     Acceptance of Receivership Appointment (Receiv...
# 4     Application and Ex Parte Order to File Lien on...
# ...                                                 ...
# 1027  Order on Petition to Discontinue Sex Offender ...
# 1028                          Acceptance of Appointment
# 1029              Assignment to Youthful Trainee Status
# 1030  Addendum to Protected Personal Identifying Inf...
# 1031      Acceptance of Appointment (Juvenile Guardian)
#
# [1032 rows x 2 columns]

# %%
G = nx.Graph()
G = nx.from_pandas_edgelist(network_df, 'form_1', 'form_2')

# %%
figure(figsize=(10, 8))
#nx.draw_shell(G) #, with_labels=True)
#nx.draw(G)
nx.draw_kamada_kawai(G)

# %%
leaderboard = {}
for x in G.nodes:
    leaderboard[x] = len(G[x])
    
s = pd.Series(leaderboard, name='connections')
df2 = s.to_frame().sort_values('connections', ascending=False)

# %%
df2[:100]
# Out:
#                                                     connections
# Assignment to Youthful Trainee Status                        17
# Ex Parte Petition Regarding Voluntary Foster Ca...           17
# Motion and Order for Discharge From Probation                15
# Answer to Complaint to Recover Possession of Pr...           14
# Addendum A to Verified Declaration About Patern...           14
# Advice of Rights after Order Terminating Parent...           14
# Addendum to Protected Personal Identifying Info...           14
# Acceptance of Appointment (Juvenile Guardian)                14
# Order on Petition to Discontinue Sex Offender R...           14
# Acceptance of Receivership Appointment (Receive...           14
# Acceptance of Appointment                                    13
# Application and Ex Parte Order to File Lien on ...           13
# Minor's Consent to Change Name                               13
# Final Statement on Garnishment of Periodic Paym...           13
# Binding Arbitration Award                                    12
# Bond, Claim and Delivery                                      6
# Affidavit Concerning Financial Status- Leave to...            6
# Clerk's Certificate of Sale of Real Estate Purs...            5

# %%
# https://github.com/WestHealth/pyvis/pull/12

# %%
net = Network(notebook=True,width="100%",height="520px")
net.from_nx(G)
if 1 == 1:
    net.set_options("""var options = {
      "nodes": {
        "font": {
          "strokeWidth": 6
        }
      },
       "layout": {
        "hierarchical": {
          "enabled": true,
          "levelSeparation": 30,
          "edgeMinimization": false
        }
      },
      "interaction": {
        "navigationButtons": true
      }
    }""")
else:
    net.width = "65%"
    #net.show_buttons()
    net.show_buttons(filter_=["layout","nodes","physics"])
    
net.show("scratch.html")
# Out:
#         <iframe
#             width="100%"
#             height="520px"
#             src="scratch.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
net.show("docs/sim/%s/network.html"%jur)
